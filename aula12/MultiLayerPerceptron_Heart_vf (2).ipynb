# %%
# Versão usando GridSerach sobre base de validação, 
# em seguida fazendo uma validação cruzada sobre o restante dos dados.

# Importa bibliotecas necessárias 
import numpy as np
from sklearn.neural_network import MLPClassifier
from sklearn import  model_selection
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn import preprocessing
import pandas as pd

from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)

# carregando a base de dados
data = pd.read_csv("heart_failure_clinical_records_dataset.csv")
#print(data)

# recupera os valores e nomes de atributos a partir do dataframe
val=data.values
att=data.columns

# preparando os arrays X (atributos de entrada) e y (rótulos)
X = val[:,0:12]
y = val[:,12]
print(X.shape)
print(y.shape)

# nomalização dos dados
#scaler = preprocessing.StandardScaler().fit(X)
#X = scaler.transform(X)

# nomalização dos dados
scaler = preprocessing.MinMaxScaler().fit(X)
X = scaler.transform(X)

#X = preprocessing.normalize(X, norm='l1', axis=0)
print(X)

# Treina o classificador
#Definição dos parâmetros a serem avaliados no ajuste fino da MLP

parameters = [
      {'solver': ['lbfgs', 'sgd', 'adam'], 'activation': ['identity', 'logistic', 'tanh', 'relu'],
       'hidden_layer_sizes': [4, 7, (6,8)], 'learning_rate_init': [0.001, 0.00001, 0.000001]},        
]


# separando uma parte para base de validação (20%)
X_train, X_val, y_train, y_val = train_test_split(X, y, train_size=0.8, random_state=42, stratify=y)


clf = MLPClassifier(random_state=10, max_iter=100, early_stopping=True, validation_fraction=0.2)

# GridSearch para customizar os parâmetros sobre base de validação
gs = GridSearchCV(clf, parameters, scoring = 'accuracy', cv=5, n_jobs=-1)
gs.fit(X_val, y_val)

from tabulate import tabulate
import pandas as pd
df=gs.cv_results_
print(tabulate(df, headers='keys', tablefmt='psql'))

print(gs.best_params_)

# validação cruzada 10-folds
folds=10
clf=gs.best_estimator_
result = model_selection.cross_val_score(clf, X_train, y_train, cv=folds, n_jobs=5)
print("\nCross Validation Results %d folds:" % folds)
print("Mean accuracy: %.5f" % result.mean())
print("Std: %.5f" % result.std())

# calculando a saída para cada instância de teste
output_prediction = model_selection.cross_val_predict(clf, X_train, y_train, cv=folds, n_jobs=5)
# calculando a matriz de confusão
cm=confusion_matrix(y_train, output_prediction)
print("Confusion Matrix:")
print(cm)
# Out:
# (299, 12)
# (299,)
# [[0.63636364 0.         0.07131921 ... 1.         0.         0.        ]
#  [0.27272727 0.         1.         ... 1.         0.         0.00711744]
#  [0.45454545 0.         0.01569278 ... 1.         1.         0.01067616]
#  ...
#  [0.09090909 0.         0.25988773 ... 0.         0.         0.97508897]
#  [0.09090909 0.         0.30492473 ... 1.         1.         0.98220641]
#  [0.18181818 0.         0.02207196 ... 1.         1.         1.        ]]
# +-----------------+----------------+-------------------+------------------+--------------------+----------------------------+----------------------------+----------------+----------------------------------------------------------------------------------------------------------+---------------------+---------------------+---------------------+---------------------+---------------------+-------------------+------------------+-------------------+
# |   mean_fit_time |   std_fit_time |   mean_score_time |   std_score_time | param_activation   | param_hidden_layer_sizes   |   param_learning_rate_init | param_solver   | params                                                                                                   |   split0_test_score |   split1_test_score |   split2_test_score |   split3_test_score |   split4_test_score |   mean_test_score |   std_test_score |   rank_test_score |
# |-----------------+----------------+-------------------+------------------+--------------------+----------------------------+----------------------------+----------------+----------------------------------------------------------------------------------------------------------+---------------------+---------------------+---------------------+---------------------+---------------------+-------------------+------------------+-------------------|
# |       0.0251579 |    0.00305006  |       0.000542402 |      2.75259e-05 | identity           | 4                          |                      0.001 | lbfgs          | {'activation': 'identity', 'hidden_layer_sizes': 4, 'learning_rate_init': 0.001, 'solver': 'lbfgs'}      |            0.75     |            0.833333 |           0.833333  |            0.833333 |            0.666667 |          0.783333 |        0.0666667 |                 1 |
# |       0.0171186 |    0.00320654  |       0.000532103 |      3.4209e-05  | identity           | 4                          |                      0.001 | sgd            | {'activation': 'identity', 'hidden_layer_sizes': 4, 'learning_rate_init': 0.001, 'solver': 'sgd'}        |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0157329 |    0.000770347 |       0.000472832 |      2.11172e-05 | identity           | 4                          |                      0.001 | adam           | {'activation': 'identity', 'hidden_layer_sizes': 4, 'learning_rate_init': 0.001, 'solver': 'adam'}       |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0237035 |    0.00238089  |       0.00050559  |      3.24378e-05 | identity           | 4                          |                      1e-05 | lbfgs          | {'activation': 'identity', 'hidden_layer_sizes': 4, 'learning_rate_init': 1e-05, 'solver': 'lbfgs'}      |            0.75     |            0.833333 |           0.833333  |            0.833333 |            0.666667 |          0.783333 |        0.0666667 |                 1 |
# |       0.0164879 |    0.00102261  |       0.000542116 |      5.01818e-05 | identity           | 4                          |                      1e-05 | sgd            | {'activation': 'identity', 'hidden_layer_sizes': 4, 'learning_rate_init': 1e-05, 'solver': 'sgd'}        |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0218514 |    0.00869141  |       0.000536299 |      3.43533e-05 | identity           | 4                          |                      1e-05 | adam           | {'activation': 'identity', 'hidden_layer_sizes': 4, 'learning_rate_init': 1e-05, 'solver': 'adam'}       |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0450128 |    0.00536305  |       0.000588989 |      3.11041e-05 | identity           | 4                          |                      1e-06 | lbfgs          | {'activation': 'identity', 'hidden_layer_sizes': 4, 'learning_rate_init': 1e-06, 'solver': 'lbfgs'}      |            0.75     |            0.833333 |           0.833333  |            0.833333 |            0.666667 |          0.783333 |        0.0666667 |                 1 |
# |       0.027244  |    0.00669597  |       0.0017148   |      0.0024641   | identity           | 4                          |                      1e-06 | sgd            | {'activation': 'identity', 'hidden_layer_sizes': 4, 'learning_rate_init': 1e-06, 'solver': 'sgd'}        |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0249682 |    0.00705441  |       0.000538111 |      6.44766e-05 | identity           | 4                          |                      1e-06 | adam           | {'activation': 'identity', 'hidden_layer_sizes': 4, 'learning_rate_init': 1e-06, 'solver': 'adam'}       |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0478928 |    0.0173547   |       0.00203276  |      0.00285371  | identity           | 7                          |                      0.001 | lbfgs          | {'activation': 'identity', 'hidden_layer_sizes': 7, 'learning_rate_init': 0.001, 'solver': 'lbfgs'}      |            0.75     |            0.833333 |           0.833333  |            0.833333 |            0.666667 |          0.783333 |        0.0666667 |                 1 |
# |       0.0540706 |    0.0256491   |       0.00183821  |      0.00276867  | identity           | 7                          |                      0.001 | sgd            | {'activation': 'identity', 'hidden_layer_sizes': 7, 'learning_rate_init': 0.001, 'solver': 'sgd'}        |            0.583333 |            0.416667 |           0.166667  |            0.416667 |            0.583333 |          0.433333 |        0.152753  |                55 |
# |       0.038085  |    0.00864237  |       0.000491619 |      4.14484e-05 | identity           | 7                          |                      0.001 | adam           | {'activation': 'identity', 'hidden_layer_sizes': 7, 'learning_rate_init': 0.001, 'solver': 'adam'}       |            0.666667 |            0.416667 |           0.0833333 |            0.416667 |            0.583333 |          0.433333 |        0.2       |                56 |
# |       0.0492777 |    0.0112044   |       0.000534916 |      1.39393e-05 | identity           | 7                          |                      1e-05 | lbfgs          | {'activation': 'identity', 'hidden_layer_sizes': 7, 'learning_rate_init': 1e-05, 'solver': 'lbfgs'}      |            0.75     |            0.833333 |           0.833333  |            0.833333 |            0.666667 |          0.783333 |        0.0666667 |                 1 |
# |       0.0306406 |    0.00637313  |       0.00054307  |      3.26501e-05 | identity           | 7                          |                      1e-05 | sgd            | {'activation': 'identity', 'hidden_layer_sizes': 7, 'learning_rate_init': 1e-05, 'solver': 'sgd'}        |            0.583333 |            0.25     |           0.25      |            0.416667 |            0.583333 |          0.416667 |        0.149071  |                58 |
# |       0.0222506 |    0.00648725  |       0.000483847 |      1.64067e-05 | identity           | 7                          |                      1e-05 | adam           | {'activation': 'identity', 'hidden_layer_sizes': 7, 'learning_rate_init': 1e-05, 'solver': 'adam'}       |            0.583333 |            0.25     |           0.25      |            0.416667 |            0.583333 |          0.416667 |        0.149071  |                58 |
# |       0.0371342 |    0.0112739   |       0.000558996 |      1.80781e-05 | identity           | 7                          |                      1e-06 | lbfgs          | {'activation': 'identity', 'hidden_layer_sizes': 7, 'learning_rate_init': 1e-06, 'solver': 'lbfgs'}      |            0.75     |            0.833333 |           0.833333  |            0.833333 |            0.666667 |          0.783333 |        0.0666667 |                 1 |
# |       0.0187943 |    0.00353664  |       0.00170836  |      0.00242519  | identity           | 7                          |                      1e-06 | sgd            | {'activation': 'identity', 'hidden_layer_sizes': 7, 'learning_rate_init': 1e-06, 'solver': 'sgd'}        |            0.583333 |            0.25     |           0.25      |            0.416667 |            0.583333 |          0.416667 |        0.149071  |                58 |
# |       0.0374755 |    0.00902026  |       0.00051136  |      2.67528e-05 | identity           | 7                          |                      1e-06 | adam           | {'activation': 'identity', 'hidden_layer_sizes': 7, 'learning_rate_init': 1e-06, 'solver': 'adam'}       |            0.583333 |            0.25     |           0.25      |            0.416667 |            0.583333 |          0.416667 |        0.149071  |                58 |
# |       0.0553047 |    0.0234804   |       0.0005651   |      3.60176e-05 | identity           | (6, 8)                     |                      0.001 | lbfgs          | {'activation': 'identity', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 0.001, 'solver': 'lbfgs'} |            0.75     |            0.833333 |           0.833333  |            0.833333 |            0.666667 |          0.783333 |        0.0666667 |                 1 |
# |       0.0326875 |    0.0120256   |       0.000541306 |      4.67166e-05 | identity           | (6, 8)                     |                      0.001 | sgd            | {'activation': 'identity', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 0.001, 'solver': 'sgd'}   |            0.25     |            0.416667 |           0.333333  |            0.666667 |            0.416667 |          0.416667 |        0.139443  |                62 |
# |       0.025452  |    0.00604491  |       0.000535202 |      3.1123e-05  | identity           | (6, 8)                     |                      0.001 | adam           | {'activation': 'identity', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 0.001, 'solver': 'adam'}  |            0.25     |            0.416667 |           0.333333  |            0.416667 |            0.416667 |          0.366667 |        0.0666667 |                71 |
# |       0.0357571 |    0.00966124  |       0.000542545 |      3.22839e-05 | identity           | (6, 8)                     |                      1e-05 | lbfgs          | {'activation': 'identity', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 1e-05, 'solver': 'lbfgs'} |            0.75     |            0.833333 |           0.833333  |            0.833333 |            0.666667 |          0.783333 |        0.0666667 |                 1 |
# |       0.0167823 |    0.000430635 |       0.000540781 |      1.94333e-05 | identity           | (6, 8)                     |                      1e-05 | sgd            | {'activation': 'identity', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 1e-05, 'solver': 'sgd'}   |            0.25     |            0.333333 |           0.416667  |            0.416667 |            0.583333 |          0.4      |        0.110554  |                63 |
# |       0.0195022 |    0.00416946  |       0.000530529 |      3.59478e-05 | identity           | (6, 8)                     |                      1e-05 | adam           | {'activation': 'identity', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 1e-05, 'solver': 'adam'}  |            0.25     |            0.333333 |           0.416667  |            0.416667 |            0.583333 |          0.4      |        0.110554  |                63 |
# |       0.0320198 |    0.00175449  |       0.00157733  |      0.00204252  | identity           | (6, 8)                     |                      1e-06 | lbfgs          | {'activation': 'identity', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 1e-06, 'solver': 'lbfgs'} |            0.75     |            0.833333 |           0.833333  |            0.833333 |            0.666667 |          0.783333 |        0.0666667 |                 1 |
# |       0.0172076 |    0.000624914 |       0.00055232  |      1.36733e-05 | identity           | (6, 8)                     |                      1e-06 | sgd            | {'activation': 'identity', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 1e-06, 'solver': 'sgd'}   |            0.25     |            0.333333 |           0.416667  |            0.416667 |            0.583333 |          0.4      |        0.110554  |                63 |
# |       0.0189477 |    0.0015746   |       0.00056982  |      3.16661e-05 | identity           | (6, 8)                     |                      1e-06 | adam           | {'activation': 'identity', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 1e-06, 'solver': 'adam'}  |            0.25     |            0.333333 |           0.416667  |            0.416667 |            0.583333 |          0.4      |        0.110554  |                63 |
# |       0.0501375 |    0.0068786   |       0.000521898 |      1.39909e-05 | logistic           | 4                          |                      0.001 | lbfgs          | {'activation': 'logistic', 'hidden_layer_sizes': 4, 'learning_rate_init': 0.001, 'solver': 'lbfgs'}      |            0.75     |            0.75     |           0.833333  |            0.833333 |            0.583333 |          0.75     |        0.0912871 |                10 |
# |       0.0155817 |    0.000143461 |       0.000529385 |      2.14172e-05 | logistic           | 4                          |                      0.001 | sgd            | {'activation': 'logistic', 'hidden_layer_sizes': 4, 'learning_rate_init': 0.001, 'solver': 'sgd'}        |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0167313 |    0.00132047  |       0.000622559 |      0.000230614 | logistic           | 4                          |                      0.001 | adam           | {'activation': 'logistic', 'hidden_layer_sizes': 4, 'learning_rate_init': 0.001, 'solver': 'adam'}       |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0568404 |    0.00889814  |       0.000516081 |      1.50741e-05 | logistic           | 4                          |                      1e-05 | lbfgs          | {'activation': 'logistic', 'hidden_layer_sizes': 4, 'learning_rate_init': 1e-05, 'solver': 'lbfgs'}      |            0.75     |            0.75     |           0.833333  |            0.833333 |            0.583333 |          0.75     |        0.0912871 |                10 |
# |       0.0151326 |    0.000140755 |       0.000487661 |      7.71033e-06 | logistic           | 4                          |                      1e-05 | sgd            | {'activation': 'logistic', 'hidden_layer_sizes': 4, 'learning_rate_init': 1e-05, 'solver': 'sgd'}        |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0160425 |    0.000602652 |       0.000526237 |      1.3644e-05  | logistic           | 4                          |                      1e-05 | adam           | {'activation': 'logistic', 'hidden_layer_sizes': 4, 'learning_rate_init': 1e-05, 'solver': 'adam'}       |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0481236 |    0.00740891  |       0.000499487 |      2.9451e-05  | logistic           | 4                          |                      1e-06 | lbfgs          | {'activation': 'logistic', 'hidden_layer_sizes': 4, 'learning_rate_init': 1e-06, 'solver': 'lbfgs'}      |            0.75     |            0.75     |           0.833333  |            0.833333 |            0.583333 |          0.75     |        0.0912871 |                10 |
# |       0.0170264 |    0.00234461  |       0.000507307 |      1.2464e-05  | logistic           | 4                          |                      1e-06 | sgd            | {'activation': 'logistic', 'hidden_layer_sizes': 4, 'learning_rate_init': 1e-06, 'solver': 'sgd'}        |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0159276 |    0.000349487 |       0.000520611 |      4.8011e-05  | logistic           | 4                          |                      1e-06 | adam           | {'activation': 'logistic', 'hidden_layer_sizes': 4, 'learning_rate_init': 1e-06, 'solver': 'adam'}       |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0570579 |    0.0138447   |       0.000540829 |      4.87006e-05 | logistic           | 7                          |                      0.001 | lbfgs          | {'activation': 'logistic', 'hidden_layer_sizes': 7, 'learning_rate_init': 0.001, 'solver': 'lbfgs'}      |            0.666667 |            0.833333 |           0.75      |            0.833333 |            0.583333 |          0.733333 |        0.0971825 |                16 |
# |       0.0155044 |    0.000981495 |       0.000520945 |      1.55152e-05 | logistic           | 7                          |                      0.001 | sgd            | {'activation': 'logistic', 'hidden_layer_sizes': 7, 'learning_rate_init': 0.001, 'solver': 'sgd'}        |            0.666667 |            0.666667 |           0.5       |            0.75     |            0.666667 |          0.65     |        0.0816497 |                38 |
# |       0.0207815 |    0.00579233  |       0.000501776 |      3.78567e-05 | logistic           | 7                          |                      0.001 | adam           | {'activation': 'logistic', 'hidden_layer_sizes': 7, 'learning_rate_init': 0.001, 'solver': 'adam'}       |            0.75     |            0.666667 |           0.583333  |            0.75     |            0.666667 |          0.683333 |        0.062361  |                34 |
# |       0.0515305 |    0.0121013   |       0.000512981 |      1.44778e-05 | logistic           | 7                          |                      1e-05 | lbfgs          | {'activation': 'logistic', 'hidden_layer_sizes': 7, 'learning_rate_init': 1e-05, 'solver': 'lbfgs'}      |            0.666667 |            0.833333 |           0.75      |            0.833333 |            0.583333 |          0.733333 |        0.0971825 |                16 |
# |       0.0159091 |    0.00159104  |       0.000469732 |      2.49989e-05 | logistic           | 7                          |                      1e-05 | sgd            | {'activation': 'logistic', 'hidden_layer_sizes': 7, 'learning_rate_init': 1e-05, 'solver': 'sgd'}        |            0.666667 |            0.666667 |           0.5       |            0.75     |            0.666667 |          0.65     |        0.0816497 |                38 |
# |       0.0184601 |    0.00562205  |       0.00050416  |      3.61229e-05 | logistic           | 7                          |                      1e-05 | adam           | {'activation': 'logistic', 'hidden_layer_sizes': 7, 'learning_rate_init': 1e-05, 'solver': 'adam'}       |            0.666667 |            0.666667 |           0.5       |            0.75     |            0.666667 |          0.65     |        0.0816497 |                38 |
# |       0.0514478 |    0.0110251   |       0.000522137 |      3.05157e-05 | logistic           | 7                          |                      1e-06 | lbfgs          | {'activation': 'logistic', 'hidden_layer_sizes': 7, 'learning_rate_init': 1e-06, 'solver': 'lbfgs'}      |            0.666667 |            0.833333 |           0.75      |            0.833333 |            0.583333 |          0.733333 |        0.0971825 |                16 |
# |       0.0156364 |    0.000697312 |       0.000520849 |      1.72234e-05 | logistic           | 7                          |                      1e-06 | sgd            | {'activation': 'logistic', 'hidden_layer_sizes': 7, 'learning_rate_init': 1e-06, 'solver': 'sgd'}        |            0.666667 |            0.666667 |           0.5       |            0.75     |            0.666667 |          0.65     |        0.0816497 |                38 |
# |       0.0164464 |    0.00031785  |       0.000496435 |      8.54377e-06 | logistic           | 7                          |                      1e-06 | adam           | {'activation': 'logistic', 'hidden_layer_sizes': 7, 'learning_rate_init': 1e-06, 'solver': 'adam'}       |            0.666667 |            0.666667 |           0.5       |            0.75     |            0.666667 |          0.65     |        0.0816497 |                38 |
# |       0.0712465 |    0.00618231  |       0.000533199 |      3.0078e-05  | logistic           | (6, 8)                     |                      0.001 | lbfgs          | {'activation': 'logistic', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 0.001, 'solver': 'lbfgs'} |            0.666667 |            0.833333 |           0.75      |            0.833333 |            0.583333 |          0.733333 |        0.0971825 |                16 |
# |       0.018101  |    0.00238053  |       0.000534248 |      1.84255e-05 | logistic           | (6, 8)                     |                      0.001 | sgd            | {'activation': 'logistic', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 0.001, 'solver': 'sgd'}   |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.018152  |    0.000356947 |       0.000504589 |      2.02679e-05 | logistic           | (6, 8)                     |                      0.001 | adam           | {'activation': 'logistic', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 0.001, 'solver': 'adam'}  |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0735564 |    0.00482853  |       0.000565052 |      2.40626e-05 | logistic           | (6, 8)                     |                      1e-05 | lbfgs          | {'activation': 'logistic', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 1e-05, 'solver': 'lbfgs'} |            0.666667 |            0.833333 |           0.75      |            0.833333 |            0.583333 |          0.733333 |        0.0971825 |                16 |
# |       0.0205143 |    0.00599511  |       0.000518322 |      4.49478e-05 | logistic           | (6, 8)                     |                      1e-05 | sgd            | {'activation': 'logistic', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 1e-05, 'solver': 'sgd'}   |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0181166 |    0.000886225 |       0.000579071 |      3.98977e-05 | logistic           | (6, 8)                     |                      1e-05 | adam           | {'activation': 'logistic', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 1e-05, 'solver': 'adam'}  |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0713257 |    0.00289147  |       0.000544167 |      1.37074e-05 | logistic           | (6, 8)                     |                      1e-06 | lbfgs          | {'activation': 'logistic', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 1e-06, 'solver': 'lbfgs'} |            0.666667 |            0.833333 |           0.75      |            0.833333 |            0.583333 |          0.733333 |        0.0971825 |                16 |
# |       0.0180374 |    0.00203881  |       0.000534773 |      1.92054e-05 | logistic           | (6, 8)                     |                      1e-06 | sgd            | {'activation': 'logistic', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 1e-06, 'solver': 'sgd'}   |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0180027 |    0.000189144 |       0.000536823 |      2.11973e-05 | logistic           | (6, 8)                     |                      1e-06 | adam           | {'activation': 'logistic', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 1e-06, 'solver': 'adam'}  |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0479486 |    0.0197066   |       0.000530577 |      2.44323e-05 | tanh               | 4                          |                      0.001 | lbfgs          | {'activation': 'tanh', 'hidden_layer_sizes': 4, 'learning_rate_init': 0.001, 'solver': 'lbfgs'}          |            0.75     |            0.666667 |           0.583333  |            0.833333 |            0.666667 |          0.7      |        0.0849837 |                31 |
# |       0.0160977 |    0.00203594  |       0.000519562 |      4.10596e-05 | tanh               | 4                          |                      0.001 | sgd            | {'activation': 'tanh', 'hidden_layer_sizes': 4, 'learning_rate_init': 0.001, 'solver': 'sgd'}            |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0160318 |    0.000203998 |       0.000479174 |      3.84312e-05 | tanh               | 4                          |                      0.001 | adam           | {'activation': 'tanh', 'hidden_layer_sizes': 4, 'learning_rate_init': 0.001, 'solver': 'adam'}           |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0482263 |    0.0211333   |       0.000528812 |      1.74284e-05 | tanh               | 4                          |                      1e-05 | lbfgs          | {'activation': 'tanh', 'hidden_layer_sizes': 4, 'learning_rate_init': 1e-05, 'solver': 'lbfgs'}          |            0.75     |            0.666667 |           0.583333  |            0.833333 |            0.666667 |          0.7      |        0.0849837 |                31 |
# |       0.0165256 |    0.00213676  |       0.000507784 |      3.24051e-05 | tanh               | 4                          |                      1e-05 | sgd            | {'activation': 'tanh', 'hidden_layer_sizes': 4, 'learning_rate_init': 1e-05, 'solver': 'sgd'}            |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0161477 |    0.00011323  |       0.000514126 |      2.19628e-05 | tanh               | 4                          |                      1e-05 | adam           | {'activation': 'tanh', 'hidden_layer_sizes': 4, 'learning_rate_init': 1e-05, 'solver': 'adam'}           |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0466271 |    0.018491    |       0.000552702 |      4.39002e-05 | tanh               | 4                          |                      1e-06 | lbfgs          | {'activation': 'tanh', 'hidden_layer_sizes': 4, 'learning_rate_init': 1e-06, 'solver': 'lbfgs'}          |            0.75     |            0.666667 |           0.583333  |            0.833333 |            0.666667 |          0.7      |        0.0849837 |                31 |
# |       0.0152658 |    0.000299507 |       0.000538588 |      2.22699e-05 | tanh               | 4                          |                      1e-06 | sgd            | {'activation': 'tanh', 'hidden_layer_sizes': 4, 'learning_rate_init': 1e-06, 'solver': 'sgd'}            |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0217492 |    0.0046894   |       0.000531244 |      2.6599e-05  | tanh               | 4                          |                      1e-06 | adam           | {'activation': 'tanh', 'hidden_layer_sizes': 4, 'learning_rate_init': 1e-06, 'solver': 'adam'}           |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0534318 |    0.0182562   |       0.000562143 |      5.22941e-05 | tanh               | 7                          |                      0.001 | lbfgs          | {'activation': 'tanh', 'hidden_layer_sizes': 7, 'learning_rate_init': 0.001, 'solver': 'lbfgs'}          |            0.833333 |            0.75     |           0.833333  |            0.666667 |            0.583333 |          0.733333 |        0.0971825 |                16 |
# |       0.015926  |    0.000740153 |       0.000493145 |      3.00701e-05 | tanh               | 7                          |                      0.001 | sgd            | {'activation': 'tanh', 'hidden_layer_sizes': 7, 'learning_rate_init': 0.001, 'solver': 'sgd'}            |            0.666667 |            0.416667 |           0.25      |            0.5      |            0.75     |          0.516667 |        0.177951  |                46 |
# |       0.0187885 |    0.00333673  |       0.000538683 |      5.39304e-05 | tanh               | 7                          |                      0.001 | adam           | {'activation': 'tanh', 'hidden_layer_sizes': 7, 'learning_rate_init': 0.001, 'solver': 'adam'}           |            0.666667 |            0.416667 |           0.25      |            0.5      |            0.833333 |          0.533333 |        0.201384  |                43 |
# |       0.0541225 |    0.018412    |       0.000528002 |      4.6149e-05  | tanh               | 7                          |                      1e-05 | lbfgs          | {'activation': 'tanh', 'hidden_layer_sizes': 7, 'learning_rate_init': 1e-05, 'solver': 'lbfgs'}          |            0.833333 |            0.75     |           0.833333  |            0.666667 |            0.583333 |          0.733333 |        0.0971825 |                16 |
# |       0.0157352 |    0.000274225 |       0.000525618 |      7.47981e-06 | tanh               | 7                          |                      1e-05 | sgd            | {'activation': 'tanh', 'hidden_layer_sizes': 7, 'learning_rate_init': 1e-05, 'solver': 'sgd'}            |            0.666667 |            0.416667 |           0.25      |            0.5      |            0.75     |          0.516667 |        0.177951  |                46 |
# |       0.0167308 |    0.00113096  |       0.000498962 |      3.53321e-05 | tanh               | 7                          |                      1e-05 | adam           | {'activation': 'tanh', 'hidden_layer_sizes': 7, 'learning_rate_init': 1e-05, 'solver': 'adam'}           |            0.666667 |            0.416667 |           0.25      |            0.5      |            0.75     |          0.516667 |        0.177951  |                46 |
# |       0.052732  |    0.0178694   |       0.000528955 |      3.08439e-05 | tanh               | 7                          |                      1e-06 | lbfgs          | {'activation': 'tanh', 'hidden_layer_sizes': 7, 'learning_rate_init': 1e-06, 'solver': 'lbfgs'}          |            0.833333 |            0.75     |           0.833333  |            0.666667 |            0.583333 |          0.733333 |        0.0971825 |                16 |
# |       0.0161241 |    0.000355338 |       0.0005476   |      4.49891e-05 | tanh               | 7                          |                      1e-06 | sgd            | {'activation': 'tanh', 'hidden_layer_sizes': 7, 'learning_rate_init': 1e-06, 'solver': 'sgd'}            |            0.666667 |            0.416667 |           0.25      |            0.5      |            0.75     |          0.516667 |        0.177951  |                46 |
# |       0.0179346 |    0.00274029  |       0.000511742 |      4.26306e-05 | tanh               | 7                          |                      1e-06 | adam           | {'activation': 'tanh', 'hidden_layer_sizes': 7, 'learning_rate_init': 1e-06, 'solver': 'adam'}           |            0.666667 |            0.416667 |           0.25      |            0.5      |            0.75     |          0.516667 |        0.177951  |                46 |
# |       0.0466359 |    0.0176567   |       0.000552225 |      3.14551e-05 | tanh               | (6, 8)                     |                      0.001 | lbfgs          | {'activation': 'tanh', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 0.001, 'solver': 'lbfgs'}     |            0.75     |            0.666667 |           0.916667  |            0.666667 |            0.583333 |          0.716667 |        0.113039  |                25 |
# |       0.0360152 |    0.0070015   |       0.000543308 |      2.26753e-05 | tanh               | (6, 8)                     |                      0.001 | sgd            | {'activation': 'tanh', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 0.001, 'solver': 'sgd'}       |            0.25     |            0.416667 |           0.333333  |            0.333333 |            0.416667 |          0.35     |        0.062361  |                72 |
# |       0.0338923 |    0.0110853   |       0.000555611 |      1.33042e-05 | tanh               | (6, 8)                     |                      0.001 | adam           | {'activation': 'tanh', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 0.001, 'solver': 'adam'}      |            0.416667 |            0.416667 |           0.333333  |            0.333333 |            0.666667 |          0.433333 |        0.122474  |                56 |
# |       0.0451259 |    0.0186346   |       0.000542927 |      1.68866e-05 | tanh               | (6, 8)                     |                      1e-05 | lbfgs          | {'activation': 'tanh', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 1e-05, 'solver': 'lbfgs'}     |            0.75     |            0.666667 |           0.916667  |            0.666667 |            0.583333 |          0.716667 |        0.113039  |                25 |
# |       0.0175686 |    0.000237706 |       0.000517797 |      2.72279e-05 | tanh               | (6, 8)                     |                      1e-05 | sgd            | {'activation': 'tanh', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 1e-05, 'solver': 'sgd'}       |            0.25     |            0.416667 |           0.333333  |            0.333333 |            0.666667 |          0.4      |        0.143372  |                63 |
# |       0.0185185 |    0.000604664 |       0.000530767 |      2.78782e-05 | tanh               | (6, 8)                     |                      1e-05 | adam           | {'activation': 'tanh', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 1e-05, 'solver': 'adam'}      |            0.25     |            0.416667 |           0.333333  |            0.333333 |            0.666667 |          0.4      |        0.143372  |                63 |
# |       0.045532  |    0.0183675   |       0.000590372 |      4.25021e-05 | tanh               | (6, 8)                     |                      1e-06 | lbfgs          | {'activation': 'tanh', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 1e-06, 'solver': 'lbfgs'}     |            0.75     |            0.666667 |           0.916667  |            0.666667 |            0.583333 |          0.716667 |        0.113039  |                25 |
# |       0.0180597 |    0.000260863 |       0.00057497  |      6.36006e-05 | tanh               | (6, 8)                     |                      1e-06 | sgd            | {'activation': 'tanh', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 1e-06, 'solver': 'sgd'}       |            0.25     |            0.416667 |           0.333333  |            0.333333 |            0.666667 |          0.4      |        0.143372  |                63 |
# |       0.0188376 |    0.000449365 |       0.000652361 |      0.00023083  | tanh               | (6, 8)                     |                      1e-06 | adam           | {'activation': 'tanh', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 1e-06, 'solver': 'adam'}      |            0.25     |            0.416667 |           0.333333  |            0.333333 |            0.666667 |          0.4      |        0.143372  |                63 |
# |       0.0718544 |    0.0241345   |       0.000558281 |      3.96339e-05 | relu               | 4                          |                      0.001 | lbfgs          | {'activation': 'relu', 'hidden_layer_sizes': 4, 'learning_rate_init': 0.001, 'solver': 'lbfgs'}          |            0.75     |            0.833333 |           0.75      |            0.75     |            0.666667 |          0.75     |        0.0527046 |                13 |
# |       0.02151   |    0.0109664   |       0.000527382 |      4.81145e-05 | relu               | 4                          |                      0.001 | sgd            | {'activation': 'relu', 'hidden_layer_sizes': 4, 'learning_rate_init': 0.001, 'solver': 'sgd'}            |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0188543 |    0.00331453  |       0.000562811 |      2.33122e-05 | relu               | 4                          |                      0.001 | adam           | {'activation': 'relu', 'hidden_layer_sizes': 4, 'learning_rate_init': 0.001, 'solver': 'adam'}           |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0745325 |    0.0220272   |       0.000607395 |      7.55537e-05 | relu               | 4                          |                      1e-05 | lbfgs          | {'activation': 'relu', 'hidden_layer_sizes': 4, 'learning_rate_init': 1e-05, 'solver': 'lbfgs'}          |            0.75     |            0.833333 |           0.75      |            0.75     |            0.666667 |          0.75     |        0.0527046 |                13 |
# |       0.015684  |    0.000533809 |       0.000499344 |      3.15047e-05 | relu               | 4                          |                      1e-05 | sgd            | {'activation': 'relu', 'hidden_layer_sizes': 4, 'learning_rate_init': 1e-05, 'solver': 'sgd'}            |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0163526 |    0.000430636 |       0.000511503 |      3.65282e-05 | relu               | 4                          |                      1e-05 | adam           | {'activation': 'relu', 'hidden_layer_sizes': 4, 'learning_rate_init': 1e-05, 'solver': 'adam'}           |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0702825 |    0.0248131   |       0.000520802 |      3.36485e-05 | relu               | 4                          |                      1e-06 | lbfgs          | {'activation': 'relu', 'hidden_layer_sizes': 4, 'learning_rate_init': 1e-06, 'solver': 'lbfgs'}          |            0.75     |            0.833333 |           0.75      |            0.75     |            0.666667 |          0.75     |        0.0527046 |                13 |
# |       0.0144279 |    0.000271902 |       0.000481415 |      4.4819e-05  | relu               | 4                          |                      1e-06 | sgd            | {'activation': 'relu', 'hidden_layer_sizes': 4, 'learning_rate_init': 1e-06, 'solver': 'sgd'}            |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0160021 |    0.000165244 |       0.000513697 |      5.30175e-05 | relu               | 4                          |                      1e-06 | adam           | {'activation': 'relu', 'hidden_layer_sizes': 4, 'learning_rate_init': 1e-06, 'solver': 'adam'}           |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0642464 |    0.0279048   |       0.000497007 |      2.67227e-05 | relu               | 7                          |                      0.001 | lbfgs          | {'activation': 'relu', 'hidden_layer_sizes': 7, 'learning_rate_init': 0.001, 'solver': 'lbfgs'}          |            0.666667 |            0.75     |           0.5       |            0.75     |            0.666667 |          0.666667 |        0.0912871 |                35 |
# |       0.0207675 |    0.00162314  |       0.000477695 |      2.96233e-05 | relu               | 7                          |                      0.001 | sgd            | {'activation': 'relu', 'hidden_layer_sizes': 7, 'learning_rate_init': 0.001, 'solver': 'sgd'}            |            0.583333 |            0.5      |           0.5       |            0.416667 |            0.583333 |          0.516667 |        0.062361  |                44 |
# |       0.0163084 |    0.000603119 |       0.00049696  |      1.87456e-05 | relu               | 7                          |                      0.001 | adam           | {'activation': 'relu', 'hidden_layer_sizes': 7, 'learning_rate_init': 0.001, 'solver': 'adam'}           |            0.583333 |            0.5      |           0.5       |            0.416667 |            0.583333 |          0.516667 |        0.062361  |                44 |
# |       0.0673419 |    0.0268815   |       0.000546122 |      5.30162e-05 | relu               | 7                          |                      1e-05 | lbfgs          | {'activation': 'relu', 'hidden_layer_sizes': 7, 'learning_rate_init': 1e-05, 'solver': 'lbfgs'}          |            0.666667 |            0.75     |           0.5       |            0.75     |            0.666667 |          0.666667 |        0.0912871 |                35 |
# |       0.0169431 |    0.00306033  |       0.000514507 |      3.99944e-05 | relu               | 7                          |                      1e-05 | sgd            | {'activation': 'relu', 'hidden_layer_sizes': 7, 'learning_rate_init': 1e-05, 'solver': 'sgd'}            |            0.583333 |            0.5      |           0.333333  |            0.416667 |            0.583333 |          0.483333 |        0.0971825 |                51 |
# |       0.016485  |    0.000253466 |       0.000543547 |      2.44778e-05 | relu               | 7                          |                      1e-05 | adam           | {'activation': 'relu', 'hidden_layer_sizes': 7, 'learning_rate_init': 1e-05, 'solver': 'adam'}           |            0.583333 |            0.5      |           0.333333  |            0.416667 |            0.583333 |          0.483333 |        0.0971825 |                51 |
# |       0.068328  |    0.025577    |       0.000535822 |      2.58772e-05 | relu               | 7                          |                      1e-06 | lbfgs          | {'activation': 'relu', 'hidden_layer_sizes': 7, 'learning_rate_init': 1e-06, 'solver': 'lbfgs'}          |            0.666667 |            0.75     |           0.5       |            0.75     |            0.666667 |          0.666667 |        0.0912871 |                35 |
# |       0.0158969 |    0.000507914 |       0.00052042  |      4.16037e-05 | relu               | 7                          |                      1e-06 | sgd            | {'activation': 'relu', 'hidden_layer_sizes': 7, 'learning_rate_init': 1e-06, 'solver': 'sgd'}            |            0.583333 |            0.5      |           0.333333  |            0.416667 |            0.583333 |          0.483333 |        0.0971825 |                51 |
# |       0.0163669 |    0.0011661   |       0.000491524 |      4.24787e-06 | relu               | 7                          |                      1e-06 | adam           | {'activation': 'relu', 'hidden_layer_sizes': 7, 'learning_rate_init': 1e-06, 'solver': 'adam'}           |            0.583333 |            0.5      |           0.333333  |            0.416667 |            0.583333 |          0.483333 |        0.0971825 |                51 |
# |       0.108845  |    0.03205     |       0.00056901  |      5.35878e-05 | relu               | (6, 8)                     |                      0.001 | lbfgs          | {'activation': 'relu', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 0.001, 'solver': 'lbfgs'}     |            0.75     |            0.833333 |           0.583333  |            0.583333 |            0.75     |          0.7      |        0.1       |                28 |
# |       0.0180223 |    0.00187369  |       0.000541592 |      4.07403e-05 | relu               | (6, 8)                     |                      0.001 | sgd            | {'activation': 'relu', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 0.001, 'solver': 'sgd'}       |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0177142 |    0.000282276 |       0.000536776 |      2.06821e-05 | relu               | (6, 8)                     |                      0.001 | adam           | {'activation': 'relu', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 0.001, 'solver': 'adam'}      |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.103803  |    0.0336916   |       0.000578308 |      7.49882e-05 | relu               | (6, 8)                     |                      1e-05 | lbfgs          | {'activation': 'relu', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 1e-05, 'solver': 'lbfgs'}     |            0.75     |            0.833333 |           0.583333  |            0.583333 |            0.75     |          0.7      |        0.1       |                28 |
# |       0.0174985 |    0.000723098 |       0.000542021 |      3.53557e-05 | relu               | (6, 8)                     |                      1e-05 | sgd            | {'activation': 'relu', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 1e-05, 'solver': 'sgd'}       |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0175124 |    0.00018027  |       0.000521994 |      1.88013e-05 | relu               | (6, 8)                     |                      1e-05 | adam           | {'activation': 'relu', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 1e-05, 'solver': 'adam'}      |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.089788  |    0.0324067   |       0.000477648 |      0.000103553 | relu               | (6, 8)                     |                      1e-06 | lbfgs          | {'activation': 'relu', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 1e-06, 'solver': 'lbfgs'}     |            0.75     |            0.833333 |           0.583333  |            0.583333 |            0.75     |          0.7      |        0.1       |                28 |
# |       0.0117593 |    0.00268951  |       0.000358105 |      8.58925e-05 | relu               | (6, 8)                     |                      1e-06 | sgd            | {'activation': 'relu', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 1e-06, 'solver': 'sgd'}       |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# |       0.0185658 |    0.000290353 |       0.000562096 |      3.54994e-05 | relu               | (6, 8)                     |                      1e-06 | adam           | {'activation': 'relu', 'hidden_layer_sizes': (6, 8), 'learning_rate_init': 1e-06, 'solver': 'adam'}      |            0.25     |            0.333333 |           0.333333  |            0.333333 |            0.333333 |          0.316667 |        0.0333333 |                73 |
# +-----------------+----------------+-------------------+------------------+--------------------+----------------------------+----------------------------+----------------+----------------------------------------------------------------------------------------------------------+---------------------+---------------------+---------------------+---------------------+---------------------+-------------------+------------------+-------------------+
# {'activation': 'identity', 'hidden_layer_sizes': 4, 'learning_rate_init': 0.001, 'solver': 'lbfgs'}
#
# Cross Validation Results 10 folds:
# Mean accuracy: 0.84094
# Std: 0.06679
# Confusion Matrix:
# [[146  16]
#  [ 22  55]]
